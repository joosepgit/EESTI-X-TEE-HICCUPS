# %%
import pandas as pd
import matplotlib.pyplot as plt
data= pd.read_csv('teste-pevas.csv')
data
# Out:
#                 DateTime  Positiivne  Negatiivne  Positiivsete testide %
# 0    2020-02-26 00:00:00           1          12                    7.69
# 1    2020-02-27 00:00:00           0          10                    0.00
# 2    2020-02-28 00:00:00           0          13                    0.00
# 3    2020-02-29 00:00:00           0           8                    0.00
# 4    2020-03-01 00:00:00           0          18                    0.00
# ..                   ...         ...         ...                     ...
# 248  2020-10-31 00:00:00          80        1113                    6.71
# 249  2020-11-01 00:00:00          61         985                    5.83
# 250  2020-11-02 00:00:00          80        1535                    4.95
# 251  2020-11-03 00:00:00         208        2448                    7.83
# 252  2020-11-04 00:00:00         131        2067                    5.96
#
# [253 rows x 4 columns]

# %%
data['Testide_arv'] = data['Positiivne']+ data['Negatiivne']

# %%
data.Testide_arv.max()
# Out:
# 3192

# %%
data.Testide_arv.idxmax()
# Out:
# 205

# %%
data.iloc[205]
# Out:
# DateTime                  2020-09-18 00:00:00
# Positiivne                                 59
# Negatiivne                               3133
# Positiivsete testide %                   1.85
# Testide_arv                              3192
# Name: 205, dtype: object

# %%
data.head()
data.to_csv('teste_pevas1.csv')

# %%
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DateTime                253 non-null    object
#  1   Positiivne              253 non-null    int64
#  2   Negatiivne              253 non-null    int64
#  3   Positiivsete testide %  253 non-null    float64
#  4   Testide_arv             253 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data['DateTime'] = pd.to_datetime(data['DateTime'], infer_datetime_format=True)

# %%
data.plot(x='DateTime', figsize=(30,10),grid=True)
plt.legend(prop={'size': 18})
plt.xticks(size = 30, color='red')
plt.yticks(size = 30, color = 'red')
plt.show()
data.head()
# Out:
#     DateTime  Positiivne  Negatiivne  Positiivsete testide %  Testide_arv
# 0 2020-02-26           1          12                    7.69           13
# 1 2020-02-27           0          10                    0.00           10
# 2 2020-02-28           0          13                    0.00           13
# 3 2020-02-29           0           8                    0.00            8
# 4 2020-03-01           0          18                    0.00           18

# %%
data= data

# %%
data_pats = pd.read_csv('pats-mai-praegu.csv')
data_pats.head()
# Out:
#    clientMemberCode   clientSubsystemCode  producerDurationProducerView  \
# 0          70009770  tis-patsiendiportaal                           NaN
# 1          70009770  tis-patsiendiportaal                           NaN
# 2          70009770  tis-patsiendiportaal                           NaN
# 3          70009770  tis-patsiendiportaal                           NaN
# 4          70009770  tis-patsiendiportaal                           NaN
#
#    requestAttachmentCount    requestInTs  requestMimeSize  requestSoapSize  \
# 0                     0.0  1588968000000              NaN             4868
# 1                     0.0  1588968000000              NaN             4388
# 2                     0.0  1588968000000              NaN             4660
# 3                     0.0  1588968000000              NaN             4656
# 4                     0.0  1588968000000              NaN             6723
#
#    responseAttachmentCount  responseMimeSize  responseSoapSize  \
# 0                      0.0               NaN            8930.0
# 1                      0.0               NaN           26978.0
# 2                      0.0               NaN           12738.0
# 3                      0.0               NaN            8804.0
# 4                      0.0               NaN           10340.0
#
#   securityServerType serviceCode  serviceMemberCode serviceSubsystemCode  \
# 0             Client         hl7           70009770             digilugu
# 1             Client         hl7           70009770             digilugu
# 2             Client         hl7           70009770             digilugu
# 3             Client         hl7           70009770             digilugu
# 4             Client         hl7           70009770             digilugu
#
#   serviceVersion  succeeded  totalDuration
# 0             v1       True         1813.0
# 1             v1       True          253.0
# 2             v1       True         1133.0
# 3             v1       True          207.0
# 4             v1       True         3864.0

# %%
data_eksam = pd.read_csv('eksam.csv')
data_eksam.head()
# Out:
#    clientMemberCode clientSubsystemCode  producerDurationProducerView  \
# 0          70008747       70008747-misp                           NaN
# 1          90005872               sais2                          73.0
# 2          90005872               sais2                           NaN
# 3          90005872               sais2                         167.0
# 4          90005872               sais2                           NaN
#
#    requestAttachmentCount    requestInTs  requestMimeSize  requestSoapSize  \
# 0                     0.0  1588924800000              NaN           2263.0
# 1                     0.0  1588968000000              NaN           1325.0
# 2                     0.0  1588968000000              NaN           1325.0
# 3                     0.0  1588968000000              NaN           1325.0
# 4                     0.0  1588968000000              NaN           1325.0
#
#    responseAttachmentCount  responseMimeSize  responseSoapSize  \
# 0                      NaN               NaN               NaN
# 1                      0.0               NaN            1591.0
# 2                      0.0               NaN            1591.0
# 3                      0.0               NaN            1591.0
# 4                      0.0               NaN            1591.0
#
#   securityServerType     serviceCode  serviceMemberCode serviceSubsystemCode  \
# 0             Client  e_tunnistus_am           90008287          eis-adapter
# 1           Producer     saisEksamid           90008287          eis-adapter
# 2             Client     saisEksamid           90008287          eis-adapter
# 3           Producer     saisEksamid           90008287          eis-adapter
# 4             Client     saisEksamid           90008287          eis-adapter
#
#   serviceVersion  succeeded  totalDuration
# 0             v1      False           44.0
# 1             v2       True            NaN
# 2             v2       True          179.0
# 3             v2       True            NaN
# 4             v2       True          286.0

# %%
data_pats_mai = pd.read_csv('pats-05.csv')
data_pats_mai.head()
# Out:
#    clientMemberCode   clientSubsystemCode  producerDurationProducerView  \
# 0          70009770  tis-patsiendiportaal                           NaN
# 1          70009770  tis-patsiendiportaal                           NaN
# 2          70009770  tis-patsiendiportaal                           NaN
# 3          70009770  tis-patsiendiportaal                           NaN
# 4          70009770  tis-patsiendiportaal                           NaN
#
#    requestAttachmentCount    requestInTs  requestMimeSize  requestSoapSize  \
# 0                     0.0  1588968000000              NaN             4868
# 1                     0.0  1588968000000              NaN             4388
# 2                     0.0  1588968000000              NaN             4660
# 3                     0.0  1588968000000              NaN             4656
# 4                     0.0  1588968000000              NaN             6723
#
#    responseAttachmentCount  responseMimeSize  responseSoapSize  \
# 0                      0.0               NaN            8930.0
# 1                      0.0               NaN           26978.0
# 2                      0.0               NaN           12738.0
# 3                      0.0               NaN            8804.0
# 4                      0.0               NaN           10340.0
#
#   securityServerType serviceCode  serviceMemberCode serviceSubsystemCode  \
# 0             Client         hl7           70009770             digilugu
# 1             Client         hl7           70009770             digilugu
# 2             Client         hl7           70009770             digilugu
# 3             Client         hl7           70009770             digilugu
# 4             Client         hl7           70009770             digilugu
#
#   serviceVersion  succeeded  totalDuration
# 0             v1       True         1813.0
# 1             v1       True          253.0
# 2             v1       True         1133.0
# 3             v1       True          207.0
# 4             v1       True         3864.0

# %%
data_pats_mai['requestInTs'] = pd.to_datetime(data_pats_mai['requestInTs'], unit='ms')
#cols16=['producerDurationProducerView','requestMimeSize','responseMimeSize','responseSoapSize','totalDuration','requestSoapSize']
#df[cols16] = df[cols16].fillna(-1).astype(np.int16)
data_pats_mai.info()
data_pats_mai.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1494519 entries, 0 to 1494518
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   clientMemberCode              1494519 non-null  int64
#  1   clientSubsystemCode           1494519 non-null  object
#  2   producerDurationProducerView  498207 non-null   float64
#  3   requestAttachmentCount        1494487 non-null  float64
#  4   requestInTs                   1494519 non-null  datetime64[ns]
#  5   requestMimeSize               0 non-null        float64
#  6   requestSoapSize               1494519 non-null  int64
#  7   responseAttachmentCount       1481138 non-null  float64
#  8   responseMimeSize              0 non-null        float64
#  9   responseSoapSize              1481138 non-null  float64
#  10  securityServerType            1494519 non-null  object
#  11  serviceCode                   1494519 non-null  object
#  12  serviceMemberCode             1494519 non-null  int64
#  13  serviceSubsystemCode          1494519 non-null  object
#  14  serviceVersion                1494519 non-null  object
#  15  succeeded                     1494519 non-null  bool
#  16  totalDuration                 996312 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(7), int64(3), object(5)
# memory usage: 183.9+ MB
#          clientMemberCode   clientSubsystemCode  producerDurationProducerView  \
# 1494509          70009770  tis-patsiendiportaal                        1475.0
# 1494510          70009770  tis-patsiendiportaal                           NaN
# 1494511          70009770  tis-patsiendiportaal                        6342.0
# 1494512          70009770  tis-patsiendiportaal                           NaN
# 1494513          70009770  tis-patsiendiportaal                         288.0
# 1494514          70009770  tis-patsiendiportaal                           NaN
# 1494515          70009770  tis-patsiendiportaal                        5347.0
# 1494516          70009770  tis-patsiendiportaal                           NaN
# 1494517          70009770  tis-patsiendiportaal                         275.0
# 1494518          70009770  tis-patsiendiportaal                           NaN
#
#          requestAttachmentCount         requestInTs  requestMimeSize  \
# 1494509                     0.0 2020-06-06 21:00:00              NaN
# 1494510                     0.0 2020-06-06 21:00:00              NaN
# 1494511                     0.0 2020-06-06 21:00:00              NaN
# 1494512                     0.0 2020-06-06 21:00:00              NaN
# 1494513                     0.0 2020-06-06 21:00:00              NaN
# 1494514                     0.0 2020-06-06 21:00:00              NaN
# 1494515                     0.0 2020-06-06 21:00:00              NaN
# 1494516                     0.0 2020-06-06 21:00:00              NaN
# 1494517                     0.0 2020-06-06 21:00:00              NaN
# 1494518                     0.0 2020-06-06 21:00:00              NaN
#
#          requestSoapSize  responseAttachmentCount  responseMimeSize  \
# 1494509             4874                      0.0               NaN
# 1494510             4874                      0.0               NaN
# 1494511             4217                      0.0               NaN
# 1494512             4217                      0.0               NaN
# 1494513             4373                      0.0               NaN
# 1494514             4373                      0.0               NaN
# 1494515             4665                      0.0               NaN
# 1494516             4665                      0.0               NaN
# 1494517             4383                      0.0               NaN
# 1494518             4383                      0.0               NaN
#
#          responseSoapSize securityServerType serviceCode  serviceMemberCode  \
# 1494509            8936.0           Producer         hl7           70009770
# 1494510            8936.0             Client         hl7           70009770
# 1494511           44289.0           Producer         hl7           70009770
# 1494512           44289.0             Client         hl7           70009770
# 1494513           27135.0           Producer         hl7           70009770
# 1494514           27135.0             Client         hl7           70009770
# 1494515          233573.0           Producer         hl7           70009770
# 1494516          233573.0             Client         hl7           70009770
# 1494517           27631.0           Producer         hl7           70009770
# 1494518           27631.0             Client         hl7           70009770
#
#         serviceSubsystemCode serviceVersion  succeeded  totalDuration
# 1494509             digilugu             v1       True            NaN
# 1494510             digilugu             v1       True         1572.0
# 1494511             digilugu             v1       True            NaN
# 1494512             digilugu             v1       True         6434.0
# 1494513             digilugu             v1       True            NaN
# 1494514             digilugu             v1       True          418.0
# 1494515             digilugu             v1       True            NaN
# 1494516             digilugu             v1       True         5407.0
# 1494517             digilugu             v1       True            NaN
# 1494518             digilugu             v1       True          384.0

# %%
data_eksam['requestInTs'] = pd.to_datetime(data_eksam['requestInTs'], unit='ms')

# %%
data_pats['requestInTs'] = pd.to_datetime(data_pats['requestInTs'], unit='ms')

# %%
#Muudab rea indeksi ajaks
timeindex=pd.DatetimeIndex(data_pats_mai['requestInTs'])
data_pats_mai1=data_pats_mai[['requestInTs']].set_index(timeindex).resample('d').count()

# %%
data_pats = data_pats.drop(data_pats[data_pats["succeeded"] == False].index)
timeindex=pd.DatetimeIndex(data_pats['requestInTs'])
data_pats1=data_pats[['requestInTs']].set_index(timeindex).resample('d').count()
data_pats1.head()
# Out:
#              requestInTs
# requestInTs
# 2020-05-07           740
# 2020-05-08         41460
# 2020-05-09         18989
# 2020-05-10         20224
# 2020-05-11         59978

# %%
timeindex=pd.DatetimeIndex(data_eksam['requestInTs'])
data_eksam1=data_eksam[['requestInTs']].set_index(timeindex).resample('d').count()

# %%
import matplotlib.pyplot as plt
data_pats_mai1.plot(y='requestInTs', figsize=(30,10),grid=True)
plt.legend(prop={'size': 18})
plt.xticks(size = 30, color='red')
plt.yticks(size = 30, color = 'red')
plt.show()

# %%
data_pats1.plot(y='requestInTs', figsize=(30,10),grid=True)
plt.legend(prop={'size': 18})
plt.xticks(size = 30, color='red')
plt.yticks(size = 30, color = 'red')
data.plot(x='DateTime', figsize=(30,10),grid=True)
plt.legend(prop={'size': 18})
plt.xticks(size = 30, color='red')
plt.yticks(size = 30, color = 'red')
plt.show()
#Koroona dataset ainult testide arvu tulbaga
data_koroona1 = data[["DateTime", "Testide_arv"]]
data_pats1.head()
data_koroona1.head()
# Out:
#     DateTime  Testide_arv
# 0 2020-02-26           13
# 1 2020-02-27           10
# 2 2020-02-28           13
# 3 2020-02-29            8
# 4 2020-03-01           18

# %%
# Kõik ÕNNESTUNUD requestid märts-nov vastavuses konkreetsel päeval tehtud testide arvuga.
# 
#
timeindex=pd.DatetimeIndex(data_koroona1['DateTime'])
data_koroona2=data_koroona1[["Testide_arv"]].set_index(timeindex)
fig1 = plt.figure(figsize=[16,8])

ax1 = fig1.add_subplot(111)
plt.xticks(size = 20, color='white')
plt.yticks(size = 20, color = 'lightblue')
ax1.plot(data_pats1["requestInTs"])
ax1.legend([ax1.get_lines()[0]], ["Patsiendiportaali päringud"])

ax2 = ax1.twinx()
ax2.plot(data_koroona2["Testide_arv"], color="red")
ax2.legend([ax2.get_lines()[0]], ["Testide arv"])
#ax2.set_ylabel("Testide_arv")
plt.yticks(size = 20, color = 'red')
plt.show()

# %%
data_eksam1.plot(y='requestInTs', figsize=(30,10),grid=True)
plt.legend(prop={'size': 18})
plt.xticks(size = 30, color='red')
plt.yticks(size = 30, color = 'red')
plt.show()
